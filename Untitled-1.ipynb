# %%
# streamlit run c:/Users/dell/Documents/GitHub/Presto_streamlit_app/data_vizualization.py

# %%
import streamlit as st
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import plotly.express as px
import matplotlib.pyplot as plt


X_feat = np.load("features_np.npy")
Y_labels = np.load("labels.npy")

print(Y_labels)
# Out:
# [2 2 2 ... 3 3 3]

# %%
# Creating dataset
# z = np.random.randint(100, size =(50))
# x = np.random.randint(80, size =(50))
# y = np.random.randint(60, size =(50))
 
# st.title('3D Scatter Plot')


# data = {'X0': X_tsne[:,0], 'X1': X_tsne[:,1], 'X2': X_tsne[:,2], 'Y_labels': Y_labels}
# df = pd.DataFrame(data)
# fig = px.scatter_3d(df, x='X0', y='X1', z='X2',
#               color='Y_labels')


# Creating figure

tsne = TSNE(n_components=3)
X_tsne = tsne.fit_transform(X_feat)
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D( X_tsne[:,0],  X_tsne[:,1],  X_tsne[:,2], color = "green")
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np


tsne = TSNE(n_components=3)
X_tsne = tsne.fit_transform(X_feat)

data = {'X0': X_tsne[:,0], 'X1': X_tsne[:,1], 'X2': X_tsne[:,2], 'Y_labels': Y_labels}
df = pd.DataFrame(data)


# Create a 3D scatter plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for each class
for cls, color in zip(df['Y_labels'].unique(), ['r', 'g', 'b', 'y']):
    ix = df['Y_labels'] == cls
    ax.scatter(df.loc[ix, 'X0'], df.loc[ix, 'X1'], df.loc[ix, 'X2'], c=color, label='Y_labels {}'.format(cls))

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('X3')
ax.set_title('3D Scatter Plot of Different Classes')
ax.legend()
fig.colorbar(ax = ax, shrink = 0.5, aspect = 5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 import pandas as pd
#       4 import numpy as np
# ----> 7 tsne = TSNE(n_components=3)
#       8 X_tsne = tsne.fit_transform(X_feat)
#      10 data = {'X0': X_tsne[:,0], 'X1': X_tsne[:,1], 'X2': X_tsne[:,2], 'Y_labels': Y_labels}
#
# NameError: name 'TSNE' is not defined

# %%
# Import libraries
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt


# Creating dataset
z = 4 * np.tan(np.random.randint(10, size =(500))) + np.random.randint(100, size =(500))
x = 4 * np.cos(z) + np.random.normal(size = 500)
y = 4 * np.sin(z) + 4 * np.random.normal(size = 500)

# Creating figure
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")

# Add x, y gridlines 
ax.grid(b = True, color ='grey', 
		linestyle ='-.', linewidth = 0.3, 
		alpha = 0.2) 


# Creating color map
my_cmap = plt.get_cmap('hsv')

# Creating plot
sctt = ax.scatter3D(x, y, z,
					alpha = 0.8,
					c = (x + y + z), 
					cmap = my_cmap, 
					marker ='^')

plt.title("simple 3D scatter plot")
ax.set_xlabel('X-axis', fontweight ='bold') 
ax.set_ylabel('Y-axis', fontweight ='bold') 
ax.set_zlabel('Z-axis', fontweight ='bold')
fig.colorbar(ax = ax, shrink = 0.5, aspect = 5)

# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 36
#      34 ax.set_ylabel('Y-axis', fontweight ='bold')
#      35 ax.set_zlabel('Z-axis', fontweight ='bold')
# ---> 36 fig.colorbar(ax = ax, shrink = 0.5, aspect = 5)
#      38 # show plot
#      39 plt.show()
#
# TypeError: FigureBase.colorbar() missing 1 required positional argument: 'mappable'

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt

image = img.imread("classification_report.jpg")
# Display the image
plt.title("Current Presto classification report")
plt.imshow(image)
plt.axis('off')  # Turn off axis
plt.show()
